# %%
import numpy as np
x = np.array([1,2,3,4], dtype=np.int64)
x.dtype
x.shape # size x and y
# Out:
# (4,)

# %%
m = np.array([[2,3,4],[5,6,7]])
# m = np.ones(5)
# m = np.zeros(2)
# m = np.eye(6) # diagonal
# m = np.random.random((2,3))
print(m[1,2])
# Out:
# 7

# %%
x = np.array([[1,2,3],[6,5,4]])
print(x.flatten()) # 1 mernii array
# Out:
# [1 2 3 6 5 4]

# %%
x.reshape((6, 1)) # rotate
# Out:
# array([[1],
#        [2],
#        [3],
#        [6],
#        [5],
#        [4]])

# %%
print(x.resize((2, 1))) # rotate with change original array
# Out:
# None

# %%
v = np.array([9,10])
w = np.array([11,12])
res = np.add(v, w)
res = np.subtract(v, w)
res = np.multiply(v, w)
res = np.dot(v, w) # scalyar
